# %%
print("----------------------------------JVVNL-----------------------------------")
print("\tToll Free Number:- 18001806507")
a=eval(input("Enter Billing month and date of issuance:-"))
b=eval(input("Contact details of subdivision"))
c=eval(input("Enter Consumer account no:-"))
d=eval(input("Consumer ‘K’ number"))
e=eval(input("Name and address of consumer"))
f=eval(input("Village census code"))
g=int(input("Mobile no. of consumer"))
h=eval(input("Consumer’s PAN no"))
i=eval(input("Direction No."))
j=eval(input("Tariff Category/Code"))
k=eval(input("Sanctioned load"))
l=eval(input("Security Deposit"))

if units<=50:
    total_bill=units*0.50
    elif units <= 150:
        total_bill=50*0.50+(units-50)*0.75
        elif units<=250:
            total_bill=50*0.50+100*0.75+(units-150)*1.20
            else:
                total_bill=50*0.50+100*0.75+100*1.20+(units-250)*1.50
                if total_bill>1000:
                    total_bill+=total_bill*0.20
print("----------------------------Electricity Consumption----------------------")
x=eval(input("Current meter reading date"))
y=eval(input("Last meter reading date"))
a1=eval(input("Last meter reading"))
b1=eval(input("Current meter reading"))
c1=eval(input("Meter No./Coefficient"))
units = float(input("Enter the number of units consumed: "))
print("Electricity Cost")
print("Fixed Charges")
print("Rent of CT/PT Transformer")
print("Unauthorized consumption charges")
print("Electricity Charges")
print("Urban Cess")
print("Water Conservation Cess")
print("Other Sundries")
print("Rebates(Rural/Sprinkler/Solar)")
print("Total Consumption Amount")
print("Balance from pervious bill")
print("------------------------------Bill Summary--------------------------------")
print("Grant by Government")
print("Electricity Bill for JVVNL: Rs.",total_bill+u)
t=eval(input("Due Date"))
u=eval(input("Late Fees"))
print("Total Payable post due date",total_bill+u)
print(d)
z=eval(input("Billing Month"))
print("Name of subdivision")
print(e)
print("Electricity Bill for JVVNL: Rs.", total_bill+u)
print("Total Payable post due date")
print("--------------------------Electricity Bill (Summary)-----------------------")
# Out:
#   Cell In[18], line 18
#     elif units <= 150:
#     ^
# SyntaxError: invalid syntax

# %%
print("----------------------------------JVVNL-----------------------------------")
print("\tToll-Free Number: 18001806507")
a = input("Enter Billing month and date of issuance: ")
b = input("Contact details of subdivision: ")
c = input("Enter Consumer account no: ")
d = input("Consumer ‘K’ number: ")
e = input("Name and address of consumer: ")
f = input("Village census code: ")
g = int(input("Mobile no. of consumer: "))
h = input("Consumer’s PAN no: ")
i = input("Direction No.: ")
j = input("Tariff Category/Code: ")
k = input("Sanctioned load: ")
l = input("Security Deposit: ")

units = float(input("Enter the number of units consumed: "))

total_bill = 0

if units <= 50:
    total_bill = units * 0.50
elif units <= 150:
    total_bill = 50 * 0.50 + (units - 50) * 0.75
elif units <= 250:
    total_bill = 50 * 0.50 + 100 * 0.75 + (units - 150) * 1.20
else:
    total_bill = 50 * 0.50 + 100 * 0.75 + 100 * 1.20 + (units - 250) * 1.50

if total_bill > 1000:
    total_bill += total_bill * 0.20

print("----------------------------Electricity Consumption----------------------")
x = input("Current meter reading date: ")
y = input("Last meter reading date: ")
a1 = eval(input("Last meter reading: "))
b1 = eval(input("Current meter reading: "))
c1 = eval(input("Meter No./Coefficient: "))

print("Electricity Cost")
print("Fixed Charges")
print("Rent of CT/PT Transformer")
print("Unauthorized consumption charges")
print("Electricity Charges")
print("Urban Cess")
print("Water Conservation Cess")
print("Other Sundries")
print("Rebates(Rural/Sprinkler/Solar)")
print("Total Consumption Amount")
print("Balance from the previous bill")

print("------------------------------Bill Summary--------------------------------")
print("Grant by Government")
print("Electricity Bill for JVVNL: Rs.", total_bill)
t = input("Due Date: ")
u = eval(input("Late Fees: "))
print("Total Payable post due date:", total_bill + u)

print("Billing Month:", a)
print("Name of subdivision:", b)
print("Name and address of consumer:", e)
print("Electricity Bill for JVVNL: Rs.", total_bill + u)
print("Total Payable post due date:", total_bill + u)
print("--------------------------Electricity Bill (Summary)-----------------------")
# Out:
# ----------------------------------JVVNL-----------------------------------
# 	Toll-Free Number: 18001806507
# Enter Billing month and date of issuance: 12-1223
# Contact details of subdivision: 180018067
# Enter Consumer account no: 5jfj94jfij
# Consumer ‘K’ number: k45643
# Name and address of consumer: Tanmayola
# Village census code: jsijf9
# Mobile no. of consumer: 8114436411
# Consumer’s PAN no: f8fh48ff\
# Direction No.: 8945
# Tariff Category/Code: 7896
# Sanctioned load: 45
# Security Deposit: 20
# Enter the number of units consumed: 75
# ----------------------------Electricity Consumption----------------------
# Current meter reading date: 1-12-23
# Last meter reading date: 1-8-23
# Last meter reading: 22900
# Current meter reading: 22975
# Meter No./Coefficient: 234567
# Electricity Cost
# Fixed Charges
# Rent of CT/PT Transformer
# Unauthorized consumption charges
# Electricity Charges
# Urban Cess
# Water Conservation Cess
# Other Sundries
# ...
